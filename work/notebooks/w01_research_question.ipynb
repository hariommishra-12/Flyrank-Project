# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hariommishra-12/Flyrank-Project/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git repo
import pandas as pd

df = pd.read_csv("repo/data/raw/content_refresh_anonymized.csv")
print("rows, cols:", df.shape)
print("distinct clients:", df["client_id"].nunique())
print(df["trend_direction"].value_counts())
# Out:
# fatal: destination path 'repo' already exists and is not an empty directory.
# rows, cols: (30000, 44)
# distinct clients: 32
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
declining_with_demand = df[(df["trend_direction"] == "down") & (df["impressions_90d"] >= 100)]

print("pages currently declining with real demand (>=100 impressions/90d):",
      len(declining_with_demand), f"({len(declining_with_demand)/len(df)*100:.1f}% of the slice)")
print("total 90-day impressions sitting on those pages:",
      f"{int(declining_with_demand['impressions_90d'].sum()):,}")
print("median 90-day impressions on those pages:",
      declining_with_demand["impressions_90d"].median())
# Out:
# pages currently declining with real demand (>=100 impressions/90d): 13152 (43.8% of the slice)
# total 90-day impressions sitting on those pages: 79,887,612
# median 90-day impressions on those pages: 1620.5

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git repo
# Out:
# fatal: destination path 'repo' already exists and is not an empty directory.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
declining_with_demand = df[(df["trend_direction"] == "down") & (df["impressions_90d"] >= 100)]
low_ctr_visible = df[
    (df["impressions_90d"] >= 500)
    & (df["avg_position"] > 0) & (df["avg_position"] <= 20)
    & (df["ctr"] < 0.5)
]

print(f"1) declining_with_demand pages: {len(declining_with_demand):,} "
      f"({len(declining_with_demand)/len(df)*100:.1f}% of {len(df):,} rows)")
print(f"   -> total impressions_90d on those pages: {int(declining_with_demand['impressions_90d'].sum()):,}")
print(f"   -> median impressions_90d on those pages: {declining_with_demand['impressions_90d'].median():,.0f}")
print()
print(f"2) low_ctr_visible_page candidates: {len(low_ctr_visible):,} "
      f"({len(low_ctr_visible)/len(df)*100:.1f}% of {len(df):,} rows)")
print()
print("3) starter model comparison (from outputs/model_report.md, this repo):")
print("   baseline rules   -> precision@50 = 0.240  (~12 of top 50 correct)")
print("   random forest    -> precision@50 = 0.740  (~37 of top 50 correct)")
# Out:
# 1) declining_with_demand pages: 13,152 (43.8% of 30,000 rows)
#    -> total impressions_90d on those pages: 79,887,612
#    -> median impressions_90d on those pages: 1,620
#
# 2) low_ctr_visible_page candidates: 9,759 (32.5% of 30,000 rows)
#
# 3) starter model comparison (from outputs/model_report.md, this repo):
#    baseline rules   -> precision@50 = 0.240  (~12 of top 50 correct)
#    random forest    -> precision@50 = 0.740  (~37 of top 50 correct)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Section 4 is a written commitment about claim language; see the markdown cell above.")
# Out:
# Section 4 is a written commitment about claim language; see the markdown cell above.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
